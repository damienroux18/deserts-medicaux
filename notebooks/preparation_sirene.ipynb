# %%
import os

import pandas as pd

# %%
# Declaration des constantes
DATA_DIR = '../data/external/'
ENTITES_FILENAME = 'StockUniteLegale_utf8.zip'
ETAB_FILENAME = 'StockEtablissement_utf8.zip'

ACTIVITY_CODE = '86.'

# %% [markdown]
# ## Préparation des Unite legales

# %%
pd.read_csv(os.path.join(DATA_DIR, ENTITES_FILENAME), # Concaténation du répertoire et du nom de fichier
           compression='zip',
           nrows=1000 # Limite a 1000 lignes la lecture
           ).head()
# Out:
#      siren statutdiffusionunitelegale unitepurgeeunitelegale  \
# 0   325175                          O                    NaN
# 1  1807254                          O                    NaN
# 2  5410220                          O                   True
# 3  5410345                          O                   True
# 4  5410394                          O                   True
#
#   datecreationunitelegale sigleunitelegale sexeunitelegale prenom1unitelegale  \
# 0              2000-09-26              NaN               M            THIERRY
# 1              1972-05-01              NaN               M     JACQUES-LUCIEN
# 2              1954-12-25              NaN               M            GEORGES
# 3                     NaN              NaN               M             MICHEL
# 4              1954-12-25              NaN               M             ROBERT
#
#   prenom2unitelegale prenom3unitelegale prenom4unitelegale  \
# 0                NaN                NaN                NaN
# 1                NaN                NaN                NaN
# 2                NaN                NaN                NaN
# 3                NaN                NaN                NaN
# 4             ALFRED                NaN                NaN
#
#                ...              denominationunitelegale  \
# 0              ...                                  NaN
# 1              ...                                  NaN
# 2              ...                                  NaN
# 3              ...                                  NaN
# 4              ...                                  NaN
#
#    denominationusuelle1unitelegale  denominationusuelle2unitelegale  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#   denominationusuelle3unitelegale  categoriejuridiqueunitelegale  \
# 0                             NaN                           1000
# 1                             NaN                           1000
# 2                             NaN                           1000
# 3                             NaN                           1000
# 4                             NaN                           1000
#
#   activiteprincipaleunitelegale  nomenclatureactiviteprincipaleunitelegale  \
# 0                        32.12Z                                    NAFRev2
# 1                        85.59A                                    NAFRev2
# 2                         22.02                                        NAP
# 3                         79.06                                        NAP
# 4                         64.42                                        NAP
#
#   nicsiegeunitelegale  economiesocialesolidaireunitelegale  \
# 0                  65                                  NaN
# 1                  22                                  NaN
# 2                  15                                  NaN
# 3                  10                                  NaN
# 4                  18                                  NaN
#
#   caractereemployeurunitelegale
# 0                             N
# 1                             N
# 2                             N
# 3                             N
# 4                             N
#
# [5 rows x 33 columns]

# %%
entite_df = (pd.read_csv(os.path.join(DATA_DIR, ENTITES_FILENAME),# Concaténation du répertoire et du nom de fichier
                        usecols=['siren','activiteprincipaleunitelegale', 'datecreationunitelegale', 'etatadministratifunitelegale',
                                'denominationunitelegale', 'nomunitelegale'
                                ],
                        compression='zip',
                        # nrows=100000 # Limite a n lignes la lecture
            )
            ).dropna(subset=['activiteprincipaleunitelegale']).query('etatadministratifunitelegale == "A"')
# Out:
# C:\Users\r12024553\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
entite_df.shape
# Out:
# (11696143, 6)

# %%
entite_df.denominationunitelegale.isnull().sum()
# Out:
# 20222

# %%
entite_df.nomunitelegale.isnull().sum()
# Out:
# 79575

# %%
entite_df.denominationunitelegale.isnull().sum() + entite_df.nomunitelegale.isnull().sum() == entite_df.shape[0]
# Out:
# True

# %%
# On filtre avec seulement les professionnels de santé
entite_df= entite_df[entite_df.activiteprincipaleunitelegale.str.startswith(ACTIVITY_CODE)]

# %%
entite_df.shape
# Out:
# (518052, 6)

# %%
entite_df.head()
# Out:
#           siren datecreationunitelegale etatadministratifunitelegale  \
# 801     5720164              1957-01-01                            A
# 4081    6540421              1965-01-01                            A
# 5775    7010457              1991-06-03                            A
# 5893    7050040              1970-01-01                            A
# 15153  17150533              1971-01-01                            A
#
#       nomunitelegale denominationunitelegale activiteprincipaleunitelegale
# 801              NaN      SA SAINTE-ISABELLE                        86.10Z
# 4081          MORONI                     NaN                        86.90A
# 5775         DACQUIN                     NaN                         86.06
# 5893             NaN       CENTRE DES CARMES                        86.10Z
# 15153            NaN    CLINIQUE LES ROSIERS                        86.10Z

# %% [markdown]
# ## Préparation des établissements

# %%
pd.read_csv(os.path.join(DATA_DIR, ETAB_FILENAME), # Concaténation du répertoire et du nom de fichier
           compression='zip',
           nrows=1000 # Limite a 1000 lignes la lecture
           ).head()
# Out:
#     siren  nic        siret statutdiffusionetablissement  \
# 0  325175   16  32517500016                            O
# 1  325175   24  32517500024                            O
# 2  325175   32  32517500032                            O
# 3  325175   40  32517500040                            O
# 4  325175   57  32517500057                            O
#
#   datecreationetablissement trancheeffectifsetablissement  \
# 0                2000-09-26                           NaN
# 1                2008-05-20                           NaN
# 2                2009-05-27                           NaN
# 3                2011-10-21                           NaN
# 4                2014-01-07                           NaN
#
#    anneeeffectifsetablissement activiteprincipaleregistremetiersetablissement  \
# 0                          NaN                                         3212ZZ
# 1                          NaN                                            NaN
# 2                          NaN                                            NaN
# 3                          NaN                                         3212ZZ
# 4                          NaN                                            NaN
#
#   datederniertraitementetablissement  etablissementsiege  \
# 0                2015-03-18T00:58:59               False
# 1                2011-12-12T09:40:04               False
# 2                2014-07-08T00:10:21               False
# 3                2015-03-18T00:58:59               False
# 4                2018-07-10T14:17:15               False
#
#                 ...                libellepaysetranger2etablissement  \
# 0               ...                                              NaN
# 1               ...                                              NaN
# 2               ...                                              NaN
# 3               ...                                              NaN
# 4               ...                                              NaN
#
#     datedebut  etatadministratifetablissement   enseigne1etablissement  \
# 0  2009-05-27                               F                      NaN
# 1  2011-10-21                               F  TAHITI PERLES CREATIONS
# 2  2011-10-21                               F  TAHITI PERLES CREATIONS
# 3  2014-01-07                               F   TAHITI PERLES CREATION
# 4  2018-02-07                               F   TAHITI PERLES CREATION
#
#   enseigne2etablissement enseigne3etablissement  \
# 0                    NaN                    NaN
# 1                    NaN                    NaN
# 2                    NaN                    NaN
# 3                    NaN                    NaN
# 4                    NaN                    NaN
#
#    denominationusuelleetablissement activiteprincipaleetablissement  \
# 0                               NaN                          32.12Z
# 1                               NaN                          47.89Z
# 2                               NaN                          32.12Z
# 3                               NaN                          32.12Z
# 4                               NaN                          32.12Z
#
#    nomenclatureactiviteprincipaleetablissement caractereemployeuretablissement
# 0                                      NAFRev2                               N
# 1                                      NAFRev2                               N
# 2                                      NAFRev2                               N
# 3                                      NAFRev2                               N
# 4                                      NAFRev2                               N
#
# [5 rows x 48 columns]

# %%
pd.read_csv(os.path.join(DATA_DIR, ETAB_FILENAME), # Concaténation du répertoire et du nom de fichier
           compression='zip',
           nrows=1000 # Limite a 1000 lignes la lecture
           ).columns
# Out:
# Index(['siren', 'nic', 'siret', 'statutdiffusionetablissement',
#        'datecreationetablissement', 'trancheeffectifsetablissement',
#        'anneeeffectifsetablissement',
#        'activiteprincipaleregistremetiersetablissement',
#        'datederniertraitementetablissement', 'etablissementsiege',
#        'nombreperiodesetablissement', 'complementadresseetablissement',
#        'numerovoieetablissement', 'indicerepetitionetablissement',
#        'typevoieetablissement', 'libellevoieetablissement',
#        'codepostaletablissement', 'libellecommuneetablissement',
#        'libellecommuneetrangeretablissement',
#        'distributionspecialeetablissement', 'codecommuneetablissement',
#        'codecedexetablissement', 'libellecedexetablissement',
#        'codepaysetrangeretablissement', 'libellepaysetrangeretablissement',
#        'complementadresse2etablissement', 'numerovoie2etablissement',
#        'indicerepetition2etablissement', 'typevoie2etablissement',
#        'libellevoie2etablissement', 'codepostal2etablissement',
#        'libellecommune2etablissement', 'libellecommuneetranger2etablissement',
#        'distributionspeciale2etablissement', 'codecommune2etablissement',
#        'codecedex2etablissement', 'libellecedex2etablissement',
#        'codepaysetranger2etablissement', 'libellepaysetranger2etablissement',
#        'datedebut', 'etatadministratifetablissement', 'enseigne1etablissement',
#        'enseigne2etablissement', 'enseigne3etablissement',
#        'denominationusuelleetablissement', 'activiteprincipaleetablissement',
#        'nomenclatureactiviteprincipaleetablissement',
#        'caractereemployeuretablissement'],
#       dtype='object')

# %%
# %%time
etab_df = (pd.read_csv(os.path.join(DATA_DIR, ETAB_FILENAME),# Concaténation du répertoire et du nom de fichier
                        usecols=['siren', 'activiteprincipaleetablissement', 'datecreationetablissement',
                                 'etatadministratifetablissement', 'denominationusuelleetablissement', 
                                 'codepostaletablissement', 'codecommuneetablissement',
                                 'libellecommuneetablissement', 'enseigne1etablissement'
                                ],
                        compression='zip',
                        #nrows=100000 # Limite a n lignes la lecture
            )
            ).dropna(subset=['activiteprincipaleetablissement']).query('etatadministratifetablissement == "A"')
# Out:
# <string>:2: DtypeWarning: Columns (20,41,44) have mixed types. Specify dtype option on import or set low_memory=False.
# Wall time: 1min 51s

# %%
#etab_df= etab_df[etab_df.activiteprincipaleetablissement.str.startswith(ACTIVITY_CODE)]

# %%
etab_df.shape
# Out:
# (11233968, 9)

# %%
etab_df.head(50)
# Out:
#        datecreationetablissement  codepostaletablissement  \
# 892                   1983-09-28                  80100.0
# 6424                  1970-01-01                   4510.0
# 17575                 1971-01-01                  21000.0
# 26233                 2002-12-19                  97600.0
# 34605                 2009-01-01                  31200.0
# 37513                 1997-01-27                   6600.0
# 41402                 1985-01-01                  39100.0
# 41851                 2004-10-01                  64100.0
# 112251                1966-01-01                  20117.0
# 112800                1967-01-01                  59500.0
# 112801                2007-11-01                  59187.0
# 117335                2004-01-19                  97600.0
# 119320                1900-01-01                  13011.0
# 121539                1955-01-01                  13011.0
# 121603                2001-10-01                  13008.0
# 123474                1956-01-01                  13400.0
# 127556                1957-01-01                  13006.0
# 127558                2003-07-31                  13008.0
# 128666                2016-06-03                  38180.0
# 138059                1961-01-01                  13009.0
# 138689                2000-07-10                  49800.0
# 138690                2003-07-01                  49800.0
# 142127                2012-03-21                  13290.0
# 142161                1963-01-01                  13600.0
# 142182                1963-01-01                  13004.0
# 142615                1998-04-01                  49300.0
# 144945                2015-02-16                  49290.0
# 146440                1993-05-18                  13011.0
# 146536                1965-01-01                  13002.0
# 146549                1965-01-01                  13600.0
# 146992                2006-08-30                  49800.0
# 146993                2015-10-12                  49800.0
# 149744                1994-09-01                  13012.0
# 150243                1967-01-01                  49370.0
# 150777                2006-06-27                  38130.0
# 151567                1967-01-01                  13600.0
# 152087                1995-01-03                  13400.0
# 152170                1967-01-01                  13400.0
# 152171                2018-10-01                  13008.0
# 154742                1968-01-01                  13190.0
# 155538                1969-01-01                  49240.0
# 157072                1969-01-01                  13011.0
# 158085                1970-01-01                  38130.0
# 165369                1972-01-01                  13008.0
# 165654                1900-01-01                  49300.0
# 165657                2008-08-25                  49300.0
# 167373                1973-01-01                  13190.0
# 167467                2016-09-05                   6600.0
# 175854                2006-05-02                  22500.0
# 178379                2013-08-01                  45770.0
#
#        libellecommuneetablissement codecommuneetablissement  \
# 892                      ABBEVILLE                    80001
# 6424                        AIGLUN                    04001
# 17575                        DIJON                    21231
# 26233                    MAMOUDZOU                    97611
# 34605                     TOULOUSE                    31555
# 37513                      ANTIBES                    06004
# 41402                         DOLE                    39198
# 41851                      BAYONNE                    64102
# 112251                       OCANA                    2A181
# 112800                       DOUAI                    59178
# 112801                       DECHY                    59170
# 117335                   MAMOUDZOU                    97611
# 119320                MARSEILLE 11                    13211
# 121539                MARSEILLE 11                    13211
# 121603                 MARSEILLE 8                    13208
# 123474                     AUBAGNE                    13005
# 127556                 MARSEILLE 6                    13206
# 127558                 MARSEILLE 8                    13208
# 128666                    SEYSSINS                    38486
# 138059                 MARSEILLE 9                    13209
# 138689                     TRELAZE                    49353
# 138690                     TRELAZE                    49353
# 142127             AIX EN PROVENCE                    13001
# 142161                    CEYRESTE                    13023
# 142182                 MARSEILLE 4                    13204
# 142615                      CHOLET                    49099
# 144945         CHALONNES SUR LOIRE                    49063
# 146440                MARSEILLE 11                    13211
# 146536                 MARSEILLE 2                    13202
# 146549                   LA CIOTAT                    13028
# 146992                     TRELAZE                    49353
# 146993                     TRELAZE                    49353
# 149744                MARSEILLE 12                    13212
# 150243         VAL D'ERDRE-AUXENCE                    49183
# 150777                  ECHIROLLES                    38151
# 151567                   LA CIOTAT                    13028
# 152087                     AUBAGNE                    13005
# 152170                     AUBAGNE                    13005
# 152171                 MARSEILLE 8                    13208
# 154742                     ALLAUCH                    13002
# 155538                     AVRILLE                    49015
# 157072                MARSEILLE 11                    13211
# 158085                  ECHIROLLES                    38151
# 165369                 MARSEILLE 8                    13208
# 165654                      CHOLET                    49099
# 165657                      CHOLET                    49099
# 167373                     ALLAUCH                    13002
# 167467                     ANTIBES                    06004
# 175854                     PAIMPOL                    22162
# 178379                       SARAN                    45302
#
#        etatadministratifetablissement  \
# 892                                 A
# 6424                                A
# 17575                               A
# 26233                               A
# 34605                               A
# 37513                               A
# 41402                               A
# 41851                               A
# 112251                              A
# 112800                              A
# 112801                              A
# 117335                              A
# 119320                              A
# 121539                              A
# 121603                              A
# 123474                              A
# 127556                              A
# 127558                              A
# 128666                              A
# 138059                              A
# 138689                              A
# 138690                              A
# 142127                              A
# 142161                              A
# 142182                              A
# 142615                              A
# 144945                              A
# 146440                              A
# 146536                              A
# 146549                              A
# 146992                              A
# 146993                              A
# 149744                              A
# 150243                              A
# 150777                              A
# 151567                              A
# 152087                              A
# 152170                              A
# 152171                              A
# 154742                              A
# 155538                              A
# 157072                              A
# 158085                              A
# 165369                              A
# 165654                              A
# 165657                              A
# 167373                              A
# 167467                              A
# 175854                              A
# 178379                              A
#
#                  denominationusuelleetablissement  \
# 892                                           NaN
# 6424                                          NaN
# 17575                                         NaN
# 26233                                         NaN
# 34605                                         NaN
# 37513                     POLE ANTIBES SAINT JEAN
# 41402                                         NaN
# 41851                                         NaN
# 112251                                        NaN
# 112800                                        NaN
# 112801                                        NaN
# 117335                                        NaN
# 119320                                        NaN
# 121539                                        NaN
# 121603                                        NaN
# 123474                                        NaN
# 127556                                        NaN
# 127558                                        NaN
# 128666                                        NaN
# 138059                                        NaN
# 138689                                        NaN
# 138690                                        NaN
# 142127                                        NaN
# 142161                                        NaN
# 142182                                        NaN
# 142615                                        NaN
# 144945  AMBULANCE TAXI CHALONNES BOULISSIERE NOEL
# 146440                                        NaN
# 146536                                        NaN
# 146549                                        NaN
# 146992                                        NaN
# 146993                                        NaN
# 149744                                        NaN
# 150243                                        NaN
# 150777                                        NaN
# 151567                                        NaN
# 152087                                        NaN
# 152170                                        NaN
# 152171                CLINIQUE PROVENCE VELODROME
# 154742                                        NaN
# 155538                                        NaN
# 157072                                        NaN
# 158085                                        NaN
# 165369                                        NaN
# 165654                                        NaN
# 165657                                        NaN
# 167373                                        NaN
# 167467                                        NaN
# 175854                       AMBULANCES GOELETTES
# 178379                                        NaN
#
#        activiteprincipaleetablissement
# 892                             86.10Z
# 6424                            86.10Z
# 17575                           86.10Z
# 26233                           86.90B
# 34605                           86.23Z
# 37513                           86.10Z
# 41402                           86.90B
# 41851                           86.21Z
# 112251                          86.10Z
# 112800                          86.10Z
# 112801                          86.10Z
# 117335                          86.21Z
# 119320                          86.10Z
# 121539                          86.10Z
# 121603                          86.10Z
# 123474                          86.10Z
# 127556                          86.10Z
# 127558                          86.10Z
# 128666                          86.10Z
# 138059                          86.10Z
# 138689                          86.10Z
# 138690                          86.10Z
# 142127                          86.10Z
# 142161                          86.10Z
# 142182                          86.10Z
# 142615                          86.21Z
# 144945                          86.90A
# 146440                          86.10Z
# 146536                          86.90B
# 146549                          86.10Z
# 146992                          86.10Z
# 146993                          86.10Z
# 149744                          86.10Z
# 150243                          86.10Z
# 150777                          86.10Z
# 151567                          86.10Z
# 152087                          86.90A
# 152170                          86.10Z
# 152171                          86.10Z
# 154742                          86.10Z
# 155538                          86.10Z
# 157072                          86.10Z
# 158085                          86.90B
# 165369                          86.10Z
# 165654                          86.10Z
# 165657                          86.10Z
# 167373                          86.10Z
# 167467                          86.10Z
# 175854                          86.90A
# 178379                          86.10Z

# %%
process_df = etab_df.merge(entite_df, on='siren', how='left')

# %%
process_df.shape
# Out:
# (11233968, 14)

# %%
process_df[process_df.activiteprincipaleunitelegale.isnull()].shape
# Out:
# (7954, 14)

# %%
etab_df.merge(entite_df, on='siren', how='outer', indicator=True)['_merge'].value_counts()
# Out:
# both          11233945
# right_only     1622950
# left_only           23
# Name: _merge, dtype: int64

# %%
etab_df.memory_usage(deep=True).sum()/(1024*1024) # En megaoctet
# Out:
# 4456.694919586182
